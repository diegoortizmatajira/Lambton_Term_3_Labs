# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %% [markdown]
# # Query Twiter to get a set of tweets
# Note: Using SNScrape, as it is easier than querying the API

# %%
query = 'toronto summer since:2022-04-01 until:2022-04-30'
result = sntwitter.TwitterSearchScraper(query) 
df = pd.DataFrame(itertools.islice(result.get_items(), 1000))

# %%
df.sample(10)
# Out:
#                                                    url  \
# 948  https://twitter.com/habsrgr8/status/1515332647...
# 613  https://twitter.com/GeorgeNozuka/status/151750...
# 269  https://twitter.com/Thomastawiarski/status/151...
# 809  https://twitter.com/cyberselves/status/1516386...
# 974  https://twitter.com/office_canary/status/15150...
# 549  https://twitter.com/TheCanadianMike/status/151...
# 44   https://twitter.com/juliedabrusin/status/15200...
# 105  https://twitter.com/YaraMohajerani/status/1519...
# 219  https://twitter.com/RsnSzn/status/151929713587...
# 1    https://twitter.com/originalchadz/status/15201...
#
#                          date  \
# 948 2022-04-16 14:13:51+00:00
# 613 2022-04-22 14:00:21+00:00
# 269 2022-04-26 23:18:11+00:00
# 809 2022-04-19 12:00:12+00:00
# 974 2022-04-15 22:27:13+00:00
# 549 2022-04-23 14:03:54+00:00
# 44  2022-04-29 15:52:07+00:00
# 105 2022-04-28 23:59:36+00:00
# 219 2022-04-27 12:47:19+00:00
# 1   2022-04-29 23:27:27+00:00
#
#                                                content  \
# 948  @jessielorraine @MooreintheAM Any planned stop...
# 613  🎥 i am working on Writing &amp; Directing a Sh...
# 269  Rolling loud coming to toronto this summer !!!...
# 809  We are thrilled to be heading to "the Olympics...
# 974  @JohnFilionTO I'm very happy Kristyn Wong-Tam ...
# 549  3 million people live in the city of Toronto, ...
# 44   Canada Summer Jobs applications are open for y...
# 105  Just got my ticket for #CollisionConf in #Toro...
# 219  Im praying for Toronto this summer 😅 everyone ...
# 1    Rolling loud in Toronto, Lil baby concert in t...
#
#                                        renderedContent                   id  \
# 948  @jessielorraine @MooreintheAM Any planned stop...  1515332647773483024
# 613  🎥 i am working on Writing &amp; Directing a Sh...  1517503579501834242
# 269  Rolling loud coming to toronto this summer !!!...  1519093512393920513
# 809  We are thrilled to be heading to "the Olympics...  1516386176890023943
# 974  @JohnFilionTO I'm very happy Kristyn Wong-Tam ...  1515094420764479491
# 549  3 million people live in the city of Toronto, ...  1517866858275299329
# 44   Canada Summer Jobs applications are open for y...  1520068419130994688
# 105  Just got my ticket for #CollisionConf in #Toro...  1519828713076150272
# 219  Im praying for Toronto this summer 😅 everyone ...  1519297135879106560
# 1    Rolling loud in Toronto, Lil baby concert in t...  1520183008430632960
#
#                                                   user  replyCount  \
# 948  {'username': 'habsrgr8', 'id': 557340131, 'dis...           0
# 613  {'username': 'GeorgeNozuka', 'id': 224418189, ...           0
# 269  {'username': 'Thomastawiarski', 'id': 30764215...           0
# 809  {'username': 'cyberselves', 'id': 913787743846...           0
# 974  {'username': 'office_canary', 'id': 1072875841...           0
# 549  {'username': 'TheCanadianMike', 'id': 54063579...           0
# 44   {'username': 'juliedabrusin', 'id': 382949896,...           1
# 105  {'username': 'YaraMohajerani', 'id': 49534192,...           0
# 219  {'username': 'RsnSzn', 'id': 14624695688956313...           0
# 1    {'username': 'originalchadz', 'id': 7765580838...           0
#
#      retweetCount  likeCount  quoteCount  ...  \
# 948             0          1           0  ...
# 613             0          4           0  ...
# 269             0          0           0  ...
# 809             0          5           0  ...
# 974             0          1           0  ...
# 549             1          1           0  ...
# 44              1          2           0  ...
# 105             1          3           0  ...
# 219             0          1           0  ...
# 1               0          0           0  ...
#
#                                                  media retweetedTweet  \
# 948                                               None           None
# 613                                               None           None
# 269                                               None           None
# 809                                               None           None
# 974                                               None           None
# 549                                               None           None
# 44   [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
# 105                                               None           None
# 219                                               None           None
# 1                                                 None           None
#
#                                            quotedTweet inReplyToTweetId  \
# 948                                               None     1.515317e+18
# 613                                               None              NaN
# 269                                               None              NaN
# 809                                               None              NaN
# 974                                               None     1.514744e+18
# 549  {'url': 'https://twitter.com/lamphieryeg/statu...              NaN
# 44                                                None              NaN
# 105                                               None              NaN
# 219                                               None              NaN
# 1                                                 None              NaN
#
#                                          inReplyToUser  \
# 948  {'username': 'jessielorraine', 'id': 25117958,...
# 613                                               None
# 269                                               None
# 809                                               None
# 974  {'username': 'JohnFilionTO', 'id': 960706196, ...
# 549                                               None
# 44                                                None
# 105                                               None
# 219                                               None
# 1                                                 None
#
#                                         mentionedUsers coordinates place  \
# 948  [{'username': 'jessielorraine', 'id': 25117958...        None  None
# 613                                               None        None  None
# 269                                               None        None  None
# 809                                               None        None  None
# 974  [{'username': 'JohnFilionTO', 'id': 960706196,...        None  None
# 549                                               None        None  None
# 44                                                None        None  None
# 105  [{'username': 'env_ai', 'id': 1359593480029425...        None  None
# 219                                               None        None  None
# 1                                                 None        None  None
#
#                      hashtags cashtags
# 948                      None     None
# 613                      None     None
# 269                      None     None
# 809           [CollisionConf]     None
# 974                      None     None
# 549                      None     None
# 44                       None     None
# 105  [CollisionConf, Toronto]     None
# 219                      None     None
# 1                        None     None
#
# [10 rows x 27 columns]

# %% [markdown]
# # Clean and vectorize the contents

# %%
import string
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('words')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
lemmatizer = WordNetLemmatizer()
words = set(nltk.corpus.words.words())
cachedStopWords = stopwords.words("english")
# Out:
# [nltk_data] Downloading package words to /home/diegoortiz/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/diegoortiz/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/diegoortiz/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/diegoortiz/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/diegoortiz/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
def clean_data(text):
    #Remove numbers
    text = str(text)
    text = re.sub(r'[0-9]+', '', text)
    #Remove all words with a lenght less than 3
    text = re.sub(r'\b\w{1,2}\b', '', text)
    #Remove punctuation
    text = "".join([word.lower() for word in text if word not in string.punctuation])
    #Tokenize
    tokens = word_tokenize(text)
    #Remove stop-words
    text = ([lemmatizer.lemmatize(word) for word in tokens if word not in cachedStopWords and word in words])
    text = " ".join([word for word in text if word not in cachedStopWords])
    return text

# %%
df['content_clean'] = df['content'].apply(lambda x: clean_data(x))

# %%
clean_df = df[['id','content_clean']]
clean_df.sample(5)
# Out:
#                       id                                      content_clean
# 759  1516539496367632400  summer insane summer better believe ready case...
# 18   1520137786967343105  registration deadline summer extended may incl...
# 277  1519078933781700609  shooting least day team assignment summer prof...
# 853  1516143620356726799  tower today explore travel walk hike vacation ...
# 568  1517614471207952386  coming sojourn right defiant summer showdown p...

# %% [markdown]
# ## Vectorize

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
vectorizer = CountVectorizer(max_df=0.9, min_df=25, token_pattern='\w+|\$[\d\.]+|\S+')
tf = vectorizer.fit_transform(clean_df['content_clean']).toarray()
# feature_set tells us what word each column in the matric represents
feature_set = vectorizer.get_feature_names_out()

# %%
tf.shape
# Out:
# (1000, 37)

# %%
feature_set
# Out:
# array(['also', 'back', 'canada', 'city', 'come', 'coming', 'day',
#        'festival', 'first', 'get', 'getting', 'going', 'gon', 'good',
#        'got', 'know', 'last', 'like', 'love', 'might', 'na', 'need',
#        'new', 'night', 'one', 'people', 'really', 'rolling', 'see',
#        'spring', 'street', 'time', 'today', 'wait', 'want', 'would',
#        'year'], dtype=object)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
df_pca = pd.DataFrame(pca.fit_transform(tf), columns = ['col1', 'col2'])

# %%
df_pca.sample(5)
# Out:
#          col1      col2
# 968 -0.114328 -0.110308
# 348  0.099765 -0.061951
# 181 -0.037717 -0.147768
# 189 -0.066938 -0.169575
# 203 -0.037717 -0.147768

# %%
df_pca.plot(kind = 'scatter', x = 'col1', y = 'col2')
# Out:
# <AxesSubplot:xlabel='col1', ylabel='col2'>

# %% [markdown]
# # Clusterize

# %%
from sklearn.cluster import KMeans

# %%
NUMBER_OF_CLUSTERS = 5
kmeans = KMeans(n_clusters=NUMBER_OF_CLUSTERS, random_state=0).fit(df_pca)
centroids = kmeans.cluster_centers_

# %%
import matplotlib.pyplot as plt
plt.scatter(df_pca['col1'], df_pca['col2'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.show()
