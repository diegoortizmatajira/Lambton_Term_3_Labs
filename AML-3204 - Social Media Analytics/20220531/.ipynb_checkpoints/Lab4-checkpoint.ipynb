# %%
# !pip install --upgrade google-api-python-client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-api-python-client in /home/diegoortiz/.local/lib/python3.10/site-packages (2.49.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /home/diegoortiz/.local/lib/python3.10/site-packages (from google-api-python-client) (0.20.4)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/diegoortiz/.local/lib/python3.10/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /home/diegoortiz/.local/lib/python3.10/site-packages (from google-api-python-client) (2.8.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.16.0 in /home/diegoortiz/.local/lib/python3.10/site-packages (from google-api-python-client) (2.6.6)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /home/diegoortiz/.local/lib/python3.10/site-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.27.1)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.15.0 in /home/diegoortiz/.local/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.19.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /home/diegoortiz/.local/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.56.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/diegoortiz/.local/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (5.1.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/lib/python3.10/site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: chardet>=3.0.2 in /usr/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (4.0.0)
# Requirement already satisfied: idna>=2.5 in /usr/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.3)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.9)

# %%
from googleapiclient.discovery import build

# %%
API_KEY = 'AIzaSyBlwx3LLpW1I8qlyCAvncNVciTJFHD2ZL0'

# %%
# create a youtube resource object
youtube = build('youtube', 'v3', developerKey=API_KEY)
comments = []
page_token = None
while True:
    # retrieve youtube video results
    response = youtube.commentThreads().list(
        part='snippet, replies',
        videoId = 'ZJ6dVVobjaI',
        pageToken = page_token
    ).execute()
    if response == None:
        break
    for item in response['items']:
        comments.append({
            'textDisplay' : item['snippet']['topLevelComment']['snippet']['textDisplay'],
            'authorProfileImageUrl' : item['snippet']['topLevelComment']['snippet']['authorProfileImageUrl'],
            'authorDisplayName' : item['snippet']['topLevelComment']['snippet']['authorDisplayName']
        })
    if not 'nextPageToken' in response:
        break
    page_token = response['nextPageToken']

# %%
import pandas as pd
df = pd.DataFrame(comments)
df
# Out:
#                                            textDisplay  \
# 0    If you are interested in these topics, you can...
# 1                     Does your robosapien still work?
# 2               hmm, I&#39;ll just use C/C++ an Python
# 3    Quick note, rust depends on libc, so it&#39;s ...
# 4                                        yay &gt; paru
# ..                                                 ...
# 236  In Italy both of these language are not popula...
# 237  Very nice video. Would be a little better with...
# 238                                        great stuff
# 239             Fair, balanced comparison.  Thank you!
# 240  Just noticed I made a typo in the JS example, ...
#
#                                  authorProfileImageUrl     authorDisplayName
# 0    https://yt3.ggpht.com/NGALI1O6CgVZKgFvgA9_jyMk...        Federico Terzi
# 1    https://yt3.ggpht.com/ytc/AKedOLS1NYJyTvf3CLrY...                 Joe G
# 2    https://yt3.ggpht.com/H6KW_7KDE5VgkGr1ei2LnEHF...  The Nerd and the Spy
# 3    https://yt3.ggpht.com/ytc/AKedOLSqWA-1cyJIftF0...         E T E R N U M
# 4    https://yt3.ggpht.com/ytc/AKedOLT7aziHROX8Gwk7...        Paul Robertson
# ..                                                 ...                   ...
# 236  https://yt3.ggpht.com/ytc/AKedOLS0A09VFxrOvH-0...         superzazzaful
# 237  https://yt3.ggpht.com/ytc/AKedOLRL7FOkcwzlrOae...     Charbel Abi Daher
# 238  https://yt3.ggpht.com/ytc/AKedOLQq7JryvVTbyn5z...        Dennis Asamoah
# 239  https://yt3.ggpht.com/ytc/AKedOLRxeGsK-n6-hoY5...            Scott Lott
# 240  https://yt3.ggpht.com/NGALI1O6CgVZKgFvgA9_jyMk...        Federico Terzi
#
# [241 rows x 3 columns]
